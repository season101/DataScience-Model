# %%
import pandas as pd
import numphy as np

# %%
dataframe = pd.read_csv('chicago_crime_data.csv')

# %%
dataframe
# Out:
#               ID Case Number                    Date                   Block  \
# 0          24392    JB323792  06/26/2018 05:16:00 PM       077XX S COLES AVE
# 1       11582357    JC136122  12/26/2018 08:00:00 AM  008XX N CHRISTIANA AVE
# 2       11582352    JC136052  12/01/2018 12:00:00 AM      030XX S KARLOV AVE
# 3       11582284    JC135308  12/20/2018 02:30:00 PM         002XX W 87TH ST
# 4       11582226    JC135263  09/01/2018 12:01:00 AM     047XX S WESTERN AVE
# ...          ...         ...                     ...                     ...
# 265377  11194525    JB103289  01/02/2018 06:00:00 PM       032XX N HOYNE AVE
# 265378     23759    JB100839  01/01/2018 06:27:00 PM   047XX S PRINCETON AVE
# 265379     23758    JB100522  01/01/2018 11:33:00 AM      026XX N HAMPDEN CT
# 265380     23757    JB100159  01/01/2018 02:46:00 AM    039XX W CORNELIA AVE
# 265381  11193631    JB102174  01/02/2018 12:30:00 PM     0000X N LA SALLE ST
#
# ...

# %%
dataframe.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0     24392    JB323792  06/26/2018 05:16:00 PM       077XX S COLES AVE  0110
# 1  11582357    JC136122  12/26/2018 08:00:00 AM  008XX N CHRISTIANA AVE  1153
# 2  11582352    JC136052  12/01/2018 12:00:00 AM      030XX S KARLOV AVE  5000
# 3  11582284    JC135308  12/20/2018 02:30:00 PM         002XX W 87TH ST  0810
# 4  11582226    JC135263  09/01/2018 12:01:00 AM     047XX S WESTERN AVE  1153
#
#          Primary Type                          Description  \
# 0            HOMICIDE                  FIRST DEGREE MURDER
# 1  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 2       OTHER OFFENSE           OTHER CRIME AGAINST PERSON
# 3               THEFT                            OVER $500
# 4  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
#
#      Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# ...

# %%
dataframe.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
dataframe.tail()
# Out:
#               ID Case Number                    Date                  Block  \
# 265377  11194525    JB103289  01/02/2018 06:00:00 PM      032XX N HOYNE AVE
# 265378     23759    JB100839  01/01/2018 06:27:00 PM  047XX S PRINCETON AVE
# 265379     23758    JB100522  01/01/2018 11:33:00 AM     026XX N HAMPDEN CT
# 265380     23757    JB100159  01/01/2018 02:46:00 AM   039XX W CORNELIA AVE
# 265381  11193631    JB102174  01/02/2018 12:30:00 PM    0000X N LA SALLE ST
#
#         IUCR Primary Type          Description    Location Description  \
# 265377  0820        THEFT       $500 AND UNDER  VEHICLE NON-COMMERCIAL
# 265378  0110     HOMICIDE  FIRST DEGREE MURDER                    AUTO
# 265379  0110     HOMICIDE  FIRST DEGREE MURDER               APARTMENT
# 265380  0110     HOMICIDE  FIRST DEGREE MURDER                    AUTO
# 265381  0870        THEFT       POCKET-PICKING              RESTAURANT
#
#         Arrest  Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# ...

# %%
dataframe.shape
# Out:
# (265382, 22)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265382 entries, 0 to 265381
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    265382 non-null  int64
#  1   Case Number           265382 non-null  object
#  2   Date                  265382 non-null  object
#  3   Block                 265382 non-null  object
#  4   IUCR                  265382 non-null  object
#  5   Primary Type          265382 non-null  object
#  6   Description           265382 non-null  object
#  7   Location Description  264637 non-null  object
#  8   Arrest                265382 non-null  bool
#  9   Domestic              265382 non-null  bool
#  10  Beat                  265382 non-null  int64
#  11  District              265382 non-null  int64
#  12  Ward                  265379 non-null  float64
#  13  Community Area        265380 non-null  float64
# ...

# %%
dataframe['FBI Code']
# Out:
# 0         01A
# 1          11
# 2          26
# 3          06
# 4          11
#          ...
# 265377     06
# 265378    01A
# 265379    01A
# 265380    01A
# 265381     06
# Name: FBI Code, Length: 265382, dtype: object

# %%
dataframe['Date'] = pd.to_datetime(dataframe['Date'])
dataframe['Update On'] = pd.to_datetime(dataframe['Updated On'])

# %%
dataframe['Date']
# Out:
# 0        2018-10-29 21:45:00
# 1        2018-10-29 13:00:00
# 2        2018-10-27 02:00:00
# 3        2018-10-24 06:00:00
# 4        2018-10-18 16:00:00
#                  ...
# 263007   2018-01-06 12:54:00
# 263008   2018-01-05 18:50:00
# 263009   2018-01-01 18:27:00
# 263010   2018-01-01 11:33:00
# 263011   2018-01-01 02:46:00
# Name: Date, Length: 263012, dtype: datetime64[ns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265382 entries, 0 to 265381
# Data columns (total 23 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    265382 non-null  int64
#  1   Case Number           265382 non-null  object
#  2   Date                  265382 non-null  datetime64[ns]
#  3   Block                 265382 non-null  object
#  4   IUCR                  265382 non-null  object
#  5   Primary Type          265382 non-null  object
#  6   Description           265382 non-null  object
#  7   Location Description  264637 non-null  object
#  8   Arrest                265382 non-null  bool
#  9   Domestic              265382 non-null  bool
#  10  Beat                  265382 non-null  int64
#  11  District              265382 non-null  int64
#  12  Ward                  265379 non-null  float64
#  13  Community Area        265380 non-null  float64
# ...

# %%
dataframe['Ward'].max()
# Out:
# 50.0

# %%
dataframe['Ward'].min()
# Out:
# 1.0

# %%
dataframe['Ward'].sum()
# Out:
# 6220338.0

# %%
dataframe['Ward'].mean()
# Out:
# 23.439450747798432

# %%
dataframe['Ward'].median()
# Out:
# 24.0

# %%
dataframe.isna().sum()
# Out:
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description     745
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                       3
# Community Area             2
# FBI Code                   0
# X Coordinate            1729
# Y Coordinate            1729
# Year                       0
# Updated On                 0
# Latitude                1729
# Longitude               1729
# Location                1729
# Update On                  0
# dtype: int64

# %%
dataframe['Ward'] = dataframe['Ward'].fillna(value=25.0)

# %%
dataframe.isna().sum()
# Out:
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description     745
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                       0
# Community Area             2
# FBI Code                   0
# X Coordinate            1729
# Y Coordinate            1729
# Year                       0
# Updated On                 0
# Latitude                1729
# Longitude               1729
# Location                1729
# Update On                  0
# dtype: int64

# %%
dataframe.dropna(axis=0,inplace=True)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 263012 entries, 6 to 265380
# Data columns (total 23 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    263012 non-null  int64
#  1   Case Number           263012 non-null  object
#  2   Date                  263012 non-null  datetime64[ns]
#  3   Block                 263012 non-null  object
#  4   IUCR                  263012 non-null  object
#  5   Primary Type          263012 non-null  object
#  6   Description           263012 non-null  object
#  7   Location Description  263012 non-null  object
#  8   Arrest                263012 non-null  bool
#  9   Domestic              263012 non-null  bool
#  10  Beat                  263012 non-null  int64
#  11  District              263012 non-null  int64
#  12  Ward                  263012 non-null  float64
#  13  Community Area        263012 non-null  float64
# ...

# %%
dataframe.reset_index(inplace=True,drop=True)

# %%
dataframe.head()
# Out:
#          ID Case Number                Date                   Block  IUCR  \
# 0  11492177    JB496165 2018-10-29 21:45:00     073XX S CHAPPEL AVE  0820
# 1  11492004    JB495913 2018-10-29 13:00:00     065XX S KIMBARK AVE  0820
# 2  11488952    JB491843 2018-10-27 02:00:00    070XX S JEFFERY BLVD  0820
# 3  11488097    JB490633 2018-10-24 06:00:00  063XX S DORCHESTER AVE  0820
# 4  11481439    JB482043 2018-10-18 16:00:00     069XX S CRANDON AVE  0820
#
#   Primary Type     Description            Location Description  Arrest  \
# 0        THEFT  $500 AND UNDER                          STREET   False
# 1        THEFT  $500 AND UNDER                          STREET   False
# 2        THEFT  $500 AND UNDER                          STREET   False
# 3        THEFT  $500 AND UNDER  PARKING LOT/GARAGE(NON.RESID.)   False
# 4        THEFT  $500 AND UNDER                       RESIDENCE   False
#
#    Domestic  ...  Community Area  FBI Code  X Coordinate  Y Coordinate  Year  \
# ...

# %%
dataframe.iloc[[67]]
# Out:
#           ID Case Number                Date               Block  IUCR  \
# 67  11549597    JB570666 2018-12-28 19:45:00  087XX S RACINE AVE  031A
#
#    Primary Type     Description Location Description  Arrest  Domestic  ...  \
# 67      ROBBERY  ARMED: HANDGUN               STREET   False     False  ...
#
#     Community Area  FBI Code  X Coordinate  Y Coordinate  Year  \
# 67            71.0        03     1169883.0     1845743.0  2018
#
#                 Updated On   Latitude  Longitude  \
# 67  01/27/2019 04:03:13 PM  41.732213 -87.653235
#
#                          Location           Update On
# 67  (41.732212896, -87.653234716) 2019-01-27 16:03:13
#
# [1 rows x 23 columns]

# %%
dataframe.iloc[2:11]
# Out:
#           ID Case Number                Date                   Block  IUCR  \
# 2   11488952    JB491843 2018-10-27 02:00:00    070XX S JEFFERY BLVD  0820
# 3   11488097    JB490633 2018-10-24 06:00:00  063XX S DORCHESTER AVE  0820
# 4   11481439    JB482043 2018-10-18 16:00:00     069XX S CRANDON AVE  0820
# 5   11480921    JB481242 2018-10-18 20:30:00     065XX S KIMBARK AVE  0820
# 6   11478932    JB478700 2018-10-16 21:30:00    061XX S WOODLAWN AVE  0820
# 7   11476211    JB475196 2018-10-14 05:00:00    071XX S JEFFERY BLVD  0820
# 8   11473764    JB471936 2018-10-06 01:00:00  072XX S SOUTH SHORE DR  0820
# 9   11469473    JB466082 2018-10-02 22:00:00    073XX S PHILLIPS AVE  0820
# 10  11465469    JB460756 2018-10-03 01:00:00     063XX S MINERVA AVE  0820
#
#    Primary Type     Description            Location Description  Arrest  \
# 2         THEFT  $500 AND UNDER                          STREET   False
# 3         THEFT  $500 AND UNDER  PARKING LOT/GARAGE(NON.RESID.)   False
# ...

# %%
dataframe[['Ward','Date']]
# Out:
#         Ward                Date
# 0        7.0 2018-10-29 21:45:00
# 1       20.0 2018-10-29 13:00:00
# 2        5.0 2018-10-27 02:00:00
# 3       20.0 2018-10-24 06:00:00
# 4        5.0 2018-10-18 16:00:00
# ...      ...                 ...
# 263007   5.0 2018-01-06 12:54:00
# 263008  28.0 2018-01-05 18:50:00
# 263009   3.0 2018-01-01 18:27:00
# 263010  43.0 2018-01-01 11:33:00
# 263011  30.0 2018-01-01 02:46:00
#
# [263012 rows x 2 columns]

# %%
dataframe[['Ward','Date']][5:11]
# Out:
#     Ward                Date
# 5   20.0 2018-10-18 20:30:00
# 6   20.0 2018-10-16 21:30:00
# 7    5.0 2018-10-14 05:00:00
# 8    7.0 2018-10-06 01:00:00
# 9    7.0 2018-10-02 22:00:00
# 10  20.0 2018-10-03 01:00:00

# %%
dataframe.iloc[5:13,5:7]
# Out:
#           Primary Type        Description
# 5                THEFT     $500 AND UNDER
# 6                THEFT     $500 AND UNDER
# 7                THEFT     $500 AND UNDER
# 8                THEFT     $500 AND UNDER
# 9                THEFT     $500 AND UNDER
# 10               THEFT     $500 AND UNDER
# 11               THEFT     $500 AND UNDER
# 12  DECEPTIVE PRACTICE  COUNTERFEIT CHECK

# %%
dataframe.iloc[[-1]]
# Out:
#            ID Case Number                Date                 Block  IUCR  \
# 263011  23757    JB100159 2018-01-01 02:46:00  039XX W CORNELIA AVE  0110
#
#        Primary Type          Description Location Description  Arrest  \
# 263011     HOMICIDE  FIRST DEGREE MURDER                 AUTO   False
#
#         Domestic  ...  Community Area  FBI Code  X Coordinate  Y Coordinate  \
# 263011     False  ...            21.0       01A     1149289.0     1922972.0
#
#         Year              Updated On   Latitude  Longitude  \
# 263011  2018  01/08/2018 03:55:29 PM  41.944561 -87.726682
#
#                              Location           Update On
# 263011  (41.944561251, -87.726681812) 2018-01-08 15:55:29
#
# [1 rows x 23 columns]

# %%
dataframe.iloc[5:15,-1]
# Out:
# 5    2019-01-30 16:08:28
# 6    2019-01-30 16:08:28
# 7    2019-01-30 16:08:28
# 8    2019-01-30 16:08:28
# 9    2019-01-30 16:08:28
# 10   2019-01-30 16:08:28
# 11   2019-01-30 16:08:28
# 12   2019-01-30 16:08:28
# 13   2019-01-30 16:08:28
# 14   2019-01-30 16:08:28
# Name: Update On, dtype: datetime64[ns]

# %%
dataframe.loc[(dataframe['Ward'] <= 35)]
# Out:
#               ID Case Number                Date                   Block  \
# 0       11492177    JB496165 2018-10-29 21:45:00     073XX S CHAPPEL AVE
# 1       11492004    JB495913 2018-10-29 13:00:00     065XX S KIMBARK AVE
# 2       11488952    JB491843 2018-10-27 02:00:00    070XX S JEFFERY BLVD
# 3       11488097    JB490633 2018-10-24 06:00:00  063XX S DORCHESTER AVE
# 4       11481439    JB482043 2018-10-18 16:00:00     069XX S CRANDON AVE
# ...          ...         ...                 ...                     ...
# 263006     23767    JB107731 2018-01-07 16:37:00  007XX N CHRISTIANA AVE
# 263007     23762    JB105277 2018-01-06 12:54:00         015XX E 62ND ST
# 263008     23763    JB105765 2018-01-05 18:50:00         053XX W LAKE ST
# 263009     23759    JB100839 2018-01-01 18:27:00   047XX S PRINCETON AVE
# 263011     23757    JB100159 2018-01-01 02:46:00    039XX W CORNELIA AVE
#
#         IUCR Primary Type          Description  \
# ...

# %%
dataframe.loc[(dataframe['Ward'] >= 35) & (dataframe['Primary Type'] == 'HOMICIDE')]
# Out:
#               ID Case Number                Date                    Block  \
# 347     11196916    JB106192 2018-01-06 04:10:00       021XX W ADDISON ST
# 447        24162    JB419467 2018-09-04 17:46:00     001XX N JEFFERSON ST
# 549        24247    JB484375 2018-10-21 16:15:00  004XX N SPRINGFIELD AVE
# 550        24219    JB465438 2018-10-06 23:39:00     022XX N KILBOURN AVE
# 553        24060    JB350722 2018-07-15 13:14:00   010XX N LEAMINGTON AVE
# ...          ...         ...                 ...                      ...
# 262993     23790    JB127183 2018-01-23 19:53:00        042XX W HIRSCH ST
# 262999     23775    JB112212 2018-01-11 12:07:00         053XX W RACE AVE
# 263001     23770    JB110156 2018-01-09 17:22:00       019XX N ALBANY AVE
# 263002     23774    JB110632 2018-01-10 03:18:00        013XX N LOREL AVE
# 263010     23758    JB100522 2018-01-01 11:33:00       026XX N HAMPDEN CT
#
#         IUCR Primary Type          Description Location Description  Arrest  \
# ...

# %%
dataframe['lat1'],dataframe['long1'] = dataframe['Location'].str.split(',',1).str
dataframe.head(6)
# Out:
# <ipython-input-109-e3207c473488>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   dataframe['lat1'],dataframe['long1'] = dataframe['Location'].str.split(',',1).str
#          ID Case Number                Date                   Block  IUCR  \
# 0  11492177    JB496165 2018-10-29 21:45:00     073XX S CHAPPEL AVE  0820
# 1  11492004    JB495913 2018-10-29 13:00:00     065XX S KIMBARK AVE  0820
# 2  11488952    JB491843 2018-10-27 02:00:00    070XX S JEFFERY BLVD  0820
# 3  11488097    JB490633 2018-10-24 06:00:00  063XX S DORCHESTER AVE  0820
# 4  11481439    JB482043 2018-10-18 16:00:00     069XX S CRANDON AVE  0820
# 5  11480921    JB481242 2018-10-18 20:30:00     065XX S KIMBARK AVE  0820
#
#   Primary Type     Description            Location Description  Arrest  \
# 0        THEFT  $500 AND UNDER                          STREET   False
# 1        THEFT  $500 AND UNDER                          STREET   False
# ...

# %%
dataframe['lat1'] = dataframe.lat1.str.replace("(","")
dataframe['long1'] = dataframe.long1.str.replace(")","")

dataframe['lat1'] = pd.to_numeric(dataframe['lat1'])
dataframe['long1'] = pd.to_numeric(dataframe['long1'])


dataframe['Geo Sum'] = dataframe['lat1'] + dataframe['long1']
dataframe.head(10)
# Out:
#          ID Case Number                Date                   Block  IUCR  \
# 0  11492177    JB496165 2018-10-29 21:45:00     073XX S CHAPPEL AVE  0820
# 1  11492004    JB495913 2018-10-29 13:00:00     065XX S KIMBARK AVE  0820
# 2  11488952    JB491843 2018-10-27 02:00:00    070XX S JEFFERY BLVD  0820
# 3  11488097    JB490633 2018-10-24 06:00:00  063XX S DORCHESTER AVE  0820
# 4  11481439    JB482043 2018-10-18 16:00:00     069XX S CRANDON AVE  0820
# 5  11480921    JB481242 2018-10-18 20:30:00     065XX S KIMBARK AVE  0820
# 6  11478932    JB478700 2018-10-16 21:30:00    061XX S WOODLAWN AVE  0820
# 7  11476211    JB475196 2018-10-14 05:00:00    071XX S JEFFERY BLVD  0820
# 8  11473764    JB471936 2018-10-06 01:00:00  072XX S SOUTH SHORE DR  0820
# 9  11469473    JB466082 2018-10-02 22:00:00    073XX S PHILLIPS AVE  0820
#
#   Primary Type     Description            Location Description  Arrest  \
# 0        THEFT  $500 AND UNDER                          STREET   False
# ...

# %%
dataframe.drop(['lat1','long1'],axis=1,inplace=True)
dataframe.head(10)
# Out:
#          ID Case Number                Date                   Block  IUCR  \
# 0  11492177    JB496165 2018-10-29 21:45:00     073XX S CHAPPEL AVE  0820
# 1  11492004    JB495913 2018-10-29 13:00:00     065XX S KIMBARK AVE  0820
# 2  11488952    JB491843 2018-10-27 02:00:00    070XX S JEFFERY BLVD  0820
# 3  11488097    JB490633 2018-10-24 06:00:00  063XX S DORCHESTER AVE  0820
# 4  11481439    JB482043 2018-10-18 16:00:00     069XX S CRANDON AVE  0820
# 5  11480921    JB481242 2018-10-18 20:30:00     065XX S KIMBARK AVE  0820
# 6  11478932    JB478700 2018-10-16 21:30:00    061XX S WOODLAWN AVE  0820
# 7  11476211    JB475196 2018-10-14 05:00:00    071XX S JEFFERY BLVD  0820
# 8  11473764    JB471936 2018-10-06 01:00:00  072XX S SOUTH SHORE DR  0820
# 9  11469473    JB466082 2018-10-02 22:00:00    073XX S PHILLIPS AVE  0820
#
#   Primary Type     Description            Location Description  Arrest  \
# 0        THEFT  $500 AND UNDER                          STREET   False
# ...

# %%
dataframe.head(10)
# Out:
#          ID Case Number                Date                   Block  IUCR  \
# 0  11492177    JB496165 2018-10-29 21:45:00     073XX S CHAPPEL AVE  0820
# 1  11492004    JB495913 2018-10-29 13:00:00     065XX S KIMBARK AVE  0820
# 2  11488952    JB491843 2018-10-27 02:00:00    070XX S JEFFERY BLVD  0820
# 3  11488097    JB490633 2018-10-24 06:00:00  063XX S DORCHESTER AVE  0820
# 4  11481439    JB482043 2018-10-18 16:00:00     069XX S CRANDON AVE  0820
# 5  11480921    JB481242 2018-10-18 20:30:00     065XX S KIMBARK AVE  0820
# 6  11478932    JB478700 2018-10-16 21:30:00    061XX S WOODLAWN AVE  0820
# 7  11476211    JB475196 2018-10-14 05:00:00    071XX S JEFFERY BLVD  0820
# 8  11473764    JB471936 2018-10-06 01:00:00  072XX S SOUTH SHORE DR  0820
# 9  11469473    JB466082 2018-10-02 22:00:00    073XX S PHILLIPS AVE  0820
#
#   Primary Type     Description            Location Description  Arrest  \
# 0        THEFT  $500 AND UNDER                          STREET   False
# ...

# %%
group_by_primarytype = dataframe.groupby(['Domestic']).count()
group_by_primarytype.head()
# Out:
#               ID  Case Number    Date   Block    IUCR  Primary Type  \
# Domestic
# False     219541       219541  219541  219541  219541        219541
# True       43471        43471   43471   43471   43471         43471
#
#           Description  Location Description  Arrest    Beat  ...  FBI Code  \
# Domestic                                                     ...
# False          219541                219541  219541  219541  ...    219541
# True            43471                 43471   43471   43471  ...     43471
#
#           X Coordinate  Y Coordinate    Year  Updated On  Latitude  Longitude  \
# Domestic
# False           219541        219541  219541      219541    219541     219541
# True             43471         43471   43471       43471     43471      43471
#
#           Location  Update On  Geo Sum
# Domestic
# False       219541     219541   219541
# True         43471      43471    43471
#
# [2 rows x 23 columns]

# %%
sorted_district = dataframe.sort_values(by=['District'], ascending=True).reset_index()
sorted_district.head()
# Out:
#     index        ID Case Number                Date                 Block  \
# 0  187716  11300274    JB243997 2018-04-30 11:30:00  002XX N MICHIGAN AVE
# 1   97533  11425237    JB403768 2018-08-21 09:30:00   002XX E RANDOLPH ST
# 2  204764  11277552    JB213608 2018-04-06 11:00:00   005XX W HARRISON ST
# 3   67590  11462685    JB457078 2018-09-30 15:19:00      0000X N STATE ST
# 4   97553  11424813    JB406347 2018-08-21 16:30:00  0000X E ROOSEVELT RD
#
#    IUCR Primary Type     Description          Location Description  Arrest  \
# 0  0890        THEFT   FROM BUILDING                    RESTAURANT   False
# 1  0560      ASSAULT          SIMPLE                     APARTMENT   False
# 2  0560      ASSAULT          SIMPLE  GOVERNMENT BUILDING/PROPERTY    True
# 3  0560      ASSAULT          SIMPLE                         OTHER   False
# 4  0820        THEFT  $500 AND UNDER   CTA GARAGE / OTHER PROPERTY   False
#
# ...

# %%
case_number = []
for i in dataframe['Case Number']:
    case_number.append(i)
print(len(case_number))
# Out:
# 263012
